# %% [markdown]
# <a href="https://colab.research.google.com/github/Kshitiz-Jain/MCA_Project/blob/master/SceneDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scenedetect
# Out:
# ...
#      |████████████████████████████████| 102kB 2.3MB/s
# ...

# %%
# %cd 'drive/My Drive/MCA_P/newvideos/'
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/MCA_P/newvideos/'
# /content/drive/My Drive/MCA_P/newvideos

# %%
# %ls
# Out:
#  absolutely-fabulous-greek-dressing.mp4
#  absolutely-the-best-chocolate-chip-cookies.mp4
#  absolute-mexican-cornbread.mp4
#  acorn-squash.mp4
#  actually-delicious-turkey-burgers.mp4
#  adams-apple-cake.mp4
#  addictive-pumpkin-muffins.mp4
#  addictive-sweet-potato-burritos.mp4
#  adriennes-cucumber-salad.mp4
#  affogato-with-cold-brewed-coffee.mp4
#  alfredo-sauce.mp4
#  alisons-rainier-bars.mp4
#  all-american-burger-dog.mp4
#  all-american-roast-beef.mp4
#  alligator-chili.mp4
#  almond-bear-claws.mp4
#  amazing-pork-tenderloin-in-the-slow-cooker.mp4
#  amazing-whole-wheat-pizza-crust.mp4
#  american-french-onion-soup.mp4
#  american-lasagna.mp4
#  amish-macaroni-salad.mp4
#  amish-white-bread.mp4
#  angels-pasta.mp4
#  annies-fruit-salsa-and-cinnamon-chips.mp4
#  antipasto-pasta-salad.mp4
#  a-number-1-banana-cake.mp4
#  apple-cinnamon-oatmeal.mp4
# 'Apple Crisp II.mp4'
#  apple-crisp-iv.mp4
#  apple-jicama-coleslaw.mp4
#  apple-oatmeal-crisp.mp4
# ...

# %%
import os

# %%
l = list(os.listdir('scene_frames/'))
done = set()
for i in l:
  temp = i.split('Scene')
  done.add(temp[0][:-1]+'.mp4')
len(done)
# Out:
# 913

# %%
done
# Out:
# {'a-simply-perfect-roast-turkey.mp4',
#  'absolute-mexican-cornbread.mp4',
#  'absolutely-fabulous-greek-dressing.mp4',
#  'absolutely-the-best-chocolate-chip-cookies.mp4',
#  'actually-delicious-turkey-burgers.mp4',
#  'adams-apple-cake.mp4',
#  'addictive-pumpkin-muffins.mp4',
#  'addictive-sweet-potato-burritos.mp4',
#  'adriennes-cucumber-salad.mp4',
#  'affogato-with-cold-brewed-coffee.mp4',
#  'alfredo-sauce.mp4',
#  'alisons-rainier-bars.mp4',
#  'all-american-burger-dog.mp4',
#  'all-american-roast-beef.mp4',
#  'almond-bear-claws.mp4',
#  'amazing-whole-wheat-pizza-crust.mp4',
#  'american-lasagna.mp4',
#  'amish-macaroni-salad.mp4',
#  'amish-white-bread.mp4',
#  'angels-pasta.mp4',
#  'apple-crisp-iv.mp4',
#  'apple-jicama-coleslaw.mp4',
#  'apple-oatmeal-crisp.mp4',
#  'apple-pie-by-grandma-ople.mp4',
#  'apple-pie-i.mp4',
#  'artichoke-spinach-dip-restaurant-style.mp4',
#  'asian-ginger-dressing.mp4',
#  'asian-lettuce-wraps.mp4',
#  'asparagus-souffle.mp4',
# ...

# %%
l = os.listdir()
for i in l:
  if i in done:
    print(i,"DONE")
    continue
  # !scenedetect --input {i} --output scene_frames detect-content save-images
  print(i)
# Out:
# cranberry-sauce.mp4 DONE
# grandmas-noodles-ii.mp4 DONE
# basic-baked-spaghetti.mp4 DONE
# sams-famous-carrot-cake.mp4 DONE
# waffles-i.mp4 DONE
# bacon-and-cranberry-bean-ragout.mp4 DONE
# marinated-grilled-shrimp.mp4 DONE
# how-to-make-san-francisco-style-bagels.mp4 DONE
# artichoke-spinach-dip-restaurant-style.mp4 DONE
# maries-easy-slow-cooker-pot-roast.mp4 DONE
# italian-salsa-di-noci.mp4 DONE
# old-fashioned-onion-rings.mp4 DONE
# gingerbread-cookies-ii.mp4 DONE
# easy-weeknight-bacon-mac-n-cheese.mp4 DONE
# grilled-lemon-rosemary-lamb-chops.mp4 DONE
# quinoa-and-black-beans.mp4 DONE
# beef-enchiladas-ii.mp4 DONE
# buttermilk-pancakes-ii.mp4 DONE
# jamies-cranberry-spinach-salad.mp4 DONE
# tartar-sauce-i.mp4 DONE
# jays-signature-pizza-crust.mp4 DONE
# the-best-vegetarian-chili-in-the-world.mp4 DONE
# black-onion-relish.mp4 DONE
# penne-with-spicy-vodka-tomato-cream-sauce.mp4 DONE
# strawberry-rhubarb-custard-pie.mp4 DONE
# apple-oatmeal-crisp.mp4 DONE
# ...
